# %% [markdown]
# <h1 align=center><font size = 5>Coursera Data Science and Machine Learning Capstone Project</font></h1>
# <h1 align=center><font size = 5>Segmenting Neighbourhood Toronto part 1 </font></h1>

# %% [markdown]
# This is data science capstone project in coursera from IBM week 3 assingment. In this project, we will cluster the neighbourhood of Toronto city using K-means clustering. In this part we will scrapping webpage to obtain the data.

# %% [markdown]
# ### Retrieving the data

# %% [markdown]
# First, we need to obtain necessary data, which is the list of neighbourhood and its coordinate of latitude and longitude. To achieve this, first we will parsing the webpage https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto to get the neighbourhood list using bs4 and then, use geopy to get the coordinate.

# %% [markdown]
# #### Import the libraries

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup 
import lxml
from geopy.geocoders import Nominatim
from geopy.geocoders import ArcGIS
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# #### Parsing the web page and getting the list of Toronto's neighbourhoods

# %%
# set the webpage address
my_url = 'https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto'

# request the webpage xml code
page = requests.get(my_url).text

# parse the webpage
# set the BeautifulSoup var 
soup = BeautifulSoup(page, 'lxml')

# Getting all district name container
district_h3 = soup.find_all("h3", limit=6)

# Getting all table containing neighbourhood list
neigh_table = soup.find_all("table", limit=6)

# %%
# define a function for saving html text from parsing result
def save_soup_text(soup_var):
    soup_text_list = []
    for i in soup_var:
        soup_text_list.append(i.find("a").text)
    return soup_text_list

# %%
# save district name in list
district_list = save_soup_text(district_h3)
print(district_list)
# Out:
# ['Old Toronto', 'East York', 'Etobicoke', 'North York', 'Scarborough', 'York']

# %%
# prepare empty dataframe to save the list of the neighbourhoods and its district name
df = pd.DataFrame(columns = ['District', 'Neighbourhood'])

# %%
# filling the dataframe with 'District', 'Neighbourhood' names

for district_name, table in zip(district_list, neigh_table):
    temp_list = []
    
    # Getting all neighbourhood list(<li>) from the table
    neigh_li = table.find_all("li") 
    
    for alist in neigh_li:
        
        # Getting neighbourhood name, save into list var in the form of pairs of district and Neighbourhood name
        temp_list.append([district_name, alist.find("a").text])
        
    # create a temp dataframe of 'District', 'Neighbourhood' for the current district_name
    temp_df = pd.DataFrame(np.array(temp_list), columns = ['District', 'Neighbourhood'])
    
    # append the temp dataframe into main dataframe
    df = df.append(temp_df, ignore_index=True)

# %%
# check the dataframe
df.head()
# Out:
#       District    Neighbourhood
# 0  Old Toronto   Alexandra Park
# 1  Old Toronto        The Annex
# 2  Old Toronto  Baldwin Village
# 3  Old Toronto      Cabbagetown
# 4  Old Toronto        CityPlace

# %%
# check the shape of dataframe
df.shape
# Out:
# (212, 2)

# %% [markdown]
# The number of neighbourhoods in the list is 212.

# %% [markdown]
# #### Retrieve the coordinate of each of neighbourhoods

# %%
# set the geolocator 
geolocator_Nominatim = Nominatim(user_agent="coursera-capstone-project")

# set the geocode function to limit the number of call per second 
geocode_Nominatim = RateLimiter(geolocator_Nominatim.geocode, min_delay_seconds=1, max_retries=5)

# ser another geolocator in case there are unretrieved coordinate using the Nominatim geolocator
geolocator_ArcGIS = ArcGIS()
geocode_ArcGIS = RateLimiter(geolocator_ArcGIS.geocode, min_delay_seconds=1, max_retries=5)

# %%
# set a column in dataframe contains strings of address to be passed as query to geolocator
df['Location'] = df['Neighbourhood'] + ', ' + df['District'] + ', ' + 'Toronto, CANADA'

# get the coordinate and put it into a new column in dataframe 
loc_data = df['Location'].apply(geocode_Nominatim)
df['Latitude'] = loc_data.apply(lambda loc: loc.latitude  if loc else np.nan)
df['Longitude'] = loc_data.apply(lambda loc: loc.longitude  if loc else np.nan)

# %%
# check the dataframe
df.head()
# Out:
#       District    Neighbourhood  \
# 0  Old Toronto   Alexandra Park
# 1  Old Toronto        The Annex
# 2  Old Toronto  Baldwin Village
# 3  Old Toronto      Cabbagetown
# 4  Old Toronto        CityPlace
#
#                                         Location   Latitude  Longitude
# 0   Alexandra Park, Old Toronto, Toronto, CANADA  43.650758 -79.404298
# 1        The Annex, Old Toronto, Toronto, CANADA  43.670338 -79.407117
# 2  Baldwin Village, Old Toronto, Toronto, CANADA        NaN        NaN
# 3      Cabbagetown, Old Toronto, Toronto, CANADA  43.664473 -79.366986
# 4        CityPlace, Old Toronto, Toronto, CANADA  43.639248 -79.396387

# %% [markdown]
# There seems to be null values in LatLongAlt column, lets check the number of missing data.

# %%
# create mask to select all rows with null value in Latitude or Longitude column
check_nan_coor = np.logical_or(df['Latitude'].isnull(),df['Longitude'].isnull())

# check the number of missing value of coordinate
print (check_nan_coor.value_counts())
print("True : missing value")
# Out:
# False    193
# True      19
# Name: Latitude, dtype: int64
# True : missing value

# %% [markdown]
# There are 19 missing data. Lets try to retrieve the coordinate of the missing data using ArcGIS geolocator.

# %%
# get the missing coordinate using ArcGIS geolocator
loc_data = df['Location'][check_nan_coor].apply(geocode_ArcGIS)
df['Latitude'][check_nan_coor] = loc_data.apply(lambda loc: loc.latitude  if loc else np.nan)
df['Longitude'][check_nan_coor] = loc_data.apply(lambda loc: loc.longitude  if loc else np.nan)
# Out:
# /home/hadji-mufushi/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/hadji-mufushi/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#       District    Neighbourhood  \
# 0  Old Toronto   Alexandra Park
# 1  Old Toronto        The Annex
# 2  Old Toronto  Baldwin Village
# 3  Old Toronto      Cabbagetown
# 4  Old Toronto        CityPlace
#
#                                         Location   Latitude  Longitude
# 0   Alexandra Park, Old Toronto, Toronto, CANADA  43.650758 -79.404298
# 1        The Annex, Old Toronto, Toronto, CANADA  43.670338 -79.407117
# 2  Baldwin Village, Old Toronto, Toronto, CANADA  43.655185 -79.397399
# 3      Cabbagetown, Old Toronto, Toronto, CANADA  43.664473 -79.366986
# 4        CityPlace, Old Toronto, Toronto, CANADA  43.639248 -79.396387

# %% [markdown]
# Lets count the number of the missing value in the coordinate column

# %%
# check the number of missing value of coordinate 
# True means the number of the missing values
missing_data= np.logical_or(df['Latitude'].isnull(),df['Longitude'].isnull())
print (missing_data.value_counts())
# Out:
# False    212
# Name: Latitude, dtype: int64

# %% [markdown]
# There is no missing coordinate for every neighbourhood. Before we save the dataframe into a csv file, lets check the neighbourhood with the same name and remove one of each that have the same coordinate.

# %%
# group dataframe by neighbourhood
grouped_df = df.groupby('Neighbourhood').count()

# check the neighbourhood with same name
grouped_df[grouped_df['Location']>1]
# Out:
#                    District  Location  Latitude  Longitude
# Neighbourhood
# Bermondsey                2         2         2          2
# East Danforth             2         2         2          2
# Queen Street West         2         2         2          2

# %% [markdown]
# Lets check the position of these neighbourhood in dataframe.

# %%
df[df['Neighbourhood'] == 'Bermondsey']
# Out:
#        District Neighbourhood                                 Location  \
# 95    East York    Bermondsey   Bermondsey, East York, Toronto, CANADA
# 133  North York    Bermondsey  Bermondsey, North York, Toronto, CANADA
#
#       Latitude  Longitude
# 95   43.713824 -79.310678
# 133  43.725405 -79.313693

# %%
df[df['Neighbourhood'] == 'East Danforth']
# Out:
#        District  Neighbourhood                                     Location  \
# 34  Old Toronto  East Danforth  East Danforth, Old Toronto, Toronto, CANADA
# 92    East York  East Danforth    East Danforth, East York, Toronto, CANADA
#
#     Latitude  Longitude
# 34  43.68636 -79.300316
# 92  43.68636 -79.300316

# %%
df[df['Neighbourhood'] == 'Queen Street West']
# Out:
#        District      Neighbourhood  \
# 23  Old Toronto  Queen Street West
# 83  Old Toronto  Queen Street West
#
#                                            Location   Latitude  Longitude
# 23  Queen Street West, Old Toronto, Toronto, CANADA  43.649852 -79.391175
# 83  Queen Street West, Old Toronto, Toronto, CANADA  43.649852 -79.391175

# %% [markdown]
# We find that each of East Danforth and Queen Street West have the same coordinate, so lets remove one row of each from the dataframe.

# %%
df.drop([83, 92], inplace = True)
df.reset_index(drop = True, inplace =True)
df
# Out:
#         District               Neighbourhood  \
# 0    Old Toronto              Alexandra Park
# 1    Old Toronto                   The Annex
# 2    Old Toronto             Baldwin Village
# 3    Old Toronto                 Cabbagetown
# 4    Old Toronto                   CityPlace
# 5    Old Toronto                   Chinatown
# 6    Old Toronto        Church and Wellesley
# 7    Old Toronto                    Corktown
# 8    Old Toronto          Discovery District
# 9    Old Toronto         Distillery District
# 10   Old Toronto  The Entertainment District
# 11   Old Toronto               East Bayfront
# 12   Old Toronto            Fashion District
# 13   Old Toronto          Financial District
# 14   Old Toronto             Garden District
# 15   Old Toronto                 Grange Park
# 16   Old Toronto             Harbord Village
# 17   Old Toronto                Harbourfront
# 18   Old Toronto           Kensington Market
# 19   Old Toronto                Little Japan
# 20   Old Toronto                   Moss Park
# 21   Old Toronto                    Old Town
# 22   Old Toronto                    Quayside
# 23   Old Toronto           Queen Street West
# 24   Old Toronto                 Regent Park
# 25   Old Toronto                  South Core
# 26   Old Toronto              St. James Town
# 27   Old Toronto                St. Lawrence
# 28   Old Toronto             Toronto Islands
# 29   Old Toronto               Trefann Court
# ..           ...                         ...
# 180  Scarborough                     Malvern
# 181  Scarborough                    Maryvale
# 182  Scarborough                    Milliken
# 183  Scarborough                 Morningside
# 184  Scarborough         Morningside Heights
# 185  Scarborough                    Oakridge
# 186  Scarborough                  Port Union
# 187  Scarborough                       Rouge
# 188  Scarborough     Scarborough City Centre
# 189  Scarborough        Scarborough Junction
# 190  Scarborough         Scarborough Village
# 191  Scarborough                     Steeles
# 192  Scarborough    Tam O'Shanter – Sullivan
# 193  Scarborough                   West Hill
# 194  Scarborough                  West Rouge
# 195  Scarborough                     Wexford
# 196  Scarborough                      Woburn
# 197         York                  Baby Point
# 198         York        Briar Hill–Belgravia
# 199         York               Eglinton West
# 200         York                    Fairbank
# 201         York          Humewood–Cedarvale
# 202         York                     Lambton
# 203         York                Mount Dennis
# 204         York             Oakwood–Vaughan
# 205         York                    Old Mill
# 206         York           Rockcliffe–Smythe
# 207         York                 Silverthorn
# 208         York                   Tichester
# 209         York                      Weston
#
#                                               Location   Latitude  Longitude
# 0         Alexandra Park, Old Toronto, Toronto, CANADA  43.650758 -79.404298
# 1              The Annex, Old Toronto, Toronto, CANADA  43.670338 -79.407117
# 2        Baldwin Village, Old Toronto, Toronto, CANADA  43.655185 -79.397399
# 3            Cabbagetown, Old Toronto, Toronto, CANADA  43.664473 -79.366986
# 4              CityPlace, Old Toronto, Toronto, CANADA  43.639248 -79.396387
# 5              Chinatown, Old Toronto, Toronto, CANADA  43.652924 -79.398032
# 6    Church and Wellesley, Old Toronto, Toronto, CA...  43.665524 -79.383801
# 7               Corktown, Old Toronto, Toronto, CANADA  43.657371 -79.356519
# 8     Discovery District, Old Toronto, Toronto, CANADA  43.657556 -79.389480
# 9    Distillery District, Old Toronto, Toronto, CANADA  43.650295 -79.359540
# 10   The Entertainment District, Old Toronto, Toron...  43.646586 -79.389723
# 11         East Bayfront, Old Toronto, Toronto, CANADA  43.790159 -79.135580
# 12      Fashion District, Old Toronto, Toronto, CANADA  43.645456 -79.394994
# 13    Financial District, Old Toronto, Toronto, CANADA  43.648664 -79.381534
# 14       Garden District, Old Toronto, Toronto, CANADA  43.656502 -79.377128
# 15           Grange Park, Old Toronto, Toronto, CANADA  43.652192 -79.392194
# 16       Harbord Village, Old Toronto, Toronto, CANADA  43.661522 -79.409745
# 17          Harbourfront, Old Toronto, Toronto, CANADA  43.640080 -79.380150
# 18     Kensington Market, Old Toronto, Toronto, CANADA  43.655214 -79.402260
# 19          Little Japan, Old Toronto, Toronto, CANADA  43.700158 -79.520278
# 20             Moss Park, Old Toronto, Toronto, CANADA  43.654644 -79.369728
# 21              Old Town, Old Toronto, Toronto, CANADA  43.659042 -79.438861
# 22              Quayside, Old Toronto, Toronto, CANADA  43.647250 -79.358172
# 23     Queen Street West, Old Toronto, Toronto, CANADA  43.649852 -79.391175
# 24           Regent Park, Old Toronto, Toronto, CANADA  43.660706 -79.360457
# 25            South Core, Old Toronto, Toronto, CANADA  43.642106 -79.377445
# 26        St. James Town, Old Toronto, Toronto, CANADA  43.669403 -79.372704
# 27          St. Lawrence, Old Toronto, Toronto, CANADA  43.649422 -79.371428
# 28       Toronto Islands, Old Toronto, Toronto, CANADA  43.616196 -79.369358
# 29         Trefann Court, Old Toronto, Toronto, CANADA  43.656489 -79.362830
# ..                                                 ...        ...        ...
# 180              Malvern, Scarborough, Toronto, CANADA  43.809196 -79.221701
# 181             Maryvale, Scarborough, Toronto, CANADA  43.759051 -79.310230
# 182             Milliken, Scarborough, Toronto, CANADA  43.823217 -79.301523
# 183          Morningside, Scarborough, Toronto, CANADA  43.782601 -79.204958
# 184  Morningside Heights, Scarborough, Toronto, CANADA  43.823700 -79.224152
# 185             Oakridge, Scarborough, Toronto, CANADA  43.697174 -79.274823
# 186           Port Union, Scarborough, Toronto, CANADA  43.775504 -79.134976
# 187                Rouge, Scarborough, Toronto, CANADA  43.804930 -79.165837
# 188  Scarborough City Centre, Scarborough, Toronto,...  43.773077 -79.257774
# 189  Scarborough Junction, Scarborough, Toronto, CA...  43.716049 -79.260703
# 190  Scarborough Village, Scarborough, Toronto, CANADA  43.743742 -79.211632
# 191              Steeles, Scarborough, Toronto, CANADA  43.816178 -79.314538
# 192  Tam O'Shanter – Sullivan, Scarborough, Toronto...  43.782512 -79.309395
# 193            West Hill, Scarborough, Toronto, CANADA  43.768914 -79.187291
# 194           West Rouge, Scarborough, Toronto, CANADA  43.785963 -79.130756
# 195              Wexford, Scarborough, Toronto, CANADA  43.745377 -79.294715
# 196               Woburn, Scarborough, Toronto, CANADA  43.759824 -79.225291
# 197                  Baby Point, York, Toronto, CANADA  43.655874 -79.496494
# 198        Briar Hill–Belgravia, York, Toronto, CANADA  43.698520 -79.451250
# 199               Eglinton West, York, Toronto, CANADA  43.699104 -79.436106
# 200                    Fairbank, York, Toronto, CANADA  43.695689 -79.450310
# 201          Humewood–Cedarvale, York, Toronto, CANADA  43.689420 -79.426980
# 202                     Lambton, York, Toronto, CANADA  43.665867 -79.499224
# 203                Mount Dennis, York, Toronto, CANADA  43.686960 -79.489551
# 204             Oakwood–Vaughan, York, Toronto, CANADA  43.691681 -79.439910
# 205                    Old Mill, York, Toronto, CANADA  43.651301 -79.495475
# 206           Rockcliffe–Smythe, York, Toronto, CANADA  43.675280 -79.488650
# 207                 Silverthorn, York, Toronto, CANADA  43.682123 -79.471572
# 208                   Tichester, York, Toronto, CANADA  43.685502 -79.418731
# 209                      Weston, York, Toronto, CANADA  43.700161 -79.516247
#
# [210 rows x 5 columns]

# %% [markdown]
# Lets save the dataframe into csv file, so that we can use it for part 2.

# %%
path = "Toronto_neighbourhood_list.csv"
df.to_csv(path, index=False)

# %% [markdown]
# ***<font size = 3>Author : Hadi Muhshi</font>***
